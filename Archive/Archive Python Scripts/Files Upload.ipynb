# %%
# !cd "C:\Users\mithu\Documents\MEGA\VUW\Summer Research Project"
# !git init
# !git add .
# !git commit -m "Initial commit"
# Out:
# Initialized empty Git repository in C:/Users/mithu/Documents/MEGA/VUW/Summer Research Project/Code Files/.git/
# ...
# [master (root-commit) cc22bdb] Initial commit
#  28 files changed, 25057 insertions(+)
#  create mode 100644 Colab/copy_of_synthetic_data_generation_(original).py
#  create mode 100644 Fornell_Larcker.csv
#  create mode 100644 PISA2022_semantic_schema_auto.csv
#  create mode 100644 PISA2022_statistical_baseline_corr.csv
#  create mode 100644 PISA2022_statistical_baseline_summary.csv
#  create mode 100644 SEM on PISA 2015.ipynb
#  create mode 100644 SEM on PISA 2022.ipynb
#  create mode 100644 SEM_results.csv
#  create mode 100644 Synthetic_Data_Generation_(CTGAN and Copula).ipynb
#  create mode 100644 bootstrapped Results/Fornell_Larcker_Bootstrapped Results.csv
#  create mode 100644 bootstrapped Results/PISA2022_semantic_schema_auto_bootstrapped_results.csv
#  create mode 100644 bootstrapped Results/PISA2022_statistical_baseline_corr_bootstrapped_results.csv
# ...

# %%
# !git remote add origin https://github.com//<your-repo>.git
# !git push -u origin main
